# %%
import pandas as pd
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]})
var2= pd.DataFrame({"C":[1,2,3,4],"D":[21,22,23,24]})
var1.join(var2)       # remember! both dataframe should contain different keys
# Out:
#    A   B  C   D
# 0  1  11  1  21
# 1  2  12  2  22
# 2  3  13  3  23
# 3  4  14  4  24

# %%
import pandas as pd
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]},index=["a","b","c","d"])
var2= pd.DataFrame({"C":[1,2],"D":[23,24]},index=["a","b"])
var1.join(var2)
# Out:
#    A   B    C     D
# a  1  11  1.0  23.0
# b  2  12  2.0  24.0
# c  3  13  NaN   NaN
# d  4  14  NaN   NaN

# %%
import pandas as pd
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]},index=["a","b","c","d"])
var2= pd.DataFrame({"C":[1,2],"D":[23,24]})
var1.join(var2)
# Out:
#    A   B   C   D
# a  1  11 NaN NaN
# b  2  12 NaN NaN
# c  3  13 NaN NaN
# d  4  14 NaN NaN

# %%
import pandas as pd
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]},index=["a","b","c","d"])
var2= pd.DataFrame({"C":[1,2],"D":[23,24]},index=["a","b"])
var2.join(var1)
# Out:
#    C   D  A   B
# a  1  23  1  11
# b  2  24  2  12

# %%
import pandas as pd
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]},index=["a","b","c","d"])
var2= pd.DataFrame({"C":[1,2],"D":[23,24]},index=["a","b"])
var1.join(var2,how="left")     # it same work as var1.join(var2)
# Out:
#    A   B    C     D
# a  1  11  1.0  23.0
# b  2  12  2.0  24.0
# c  3  13  NaN   NaN
# d  4  14  NaN   NaN

# %%
import pandas as pd
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]},index=["a","b","c","d"])
var2= pd.DataFrame({"C":[1,2],"D":[23,24]},index=["a","b"])
var1.join(var2,how="right")    # var2.join(var1)
# Out:
#    A   B  C   D
# a  1  11  1  23
# b  2  12  2  24

# %%
import pandas as pd
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]},index=["a","b","c","d"])
var2= pd.DataFrame({"C":[1,2],"D":[23,24]},index=["a","b"])
var2.join(var1,how="outer")
# Out:
#      C     D  A   B
# a  1.0  23.0  1  11
# b  2.0  24.0  2  12
# c  NaN   NaN  3  13
# d  NaN   NaN  4  14

# %%
import pandas as pd
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]},index=["a","b","c","d"])
var2= pd.DataFrame({"C":[1,2],"D":[23,24]},index=["a","b"])
var2.join(var1,how="inner")
# Out:
#    C   D  A   B
# a  1  23  1  11
# b  2  24  2  12

# %%
import pandas as pd
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]},index=["a","b","c","d"])
var2= pd.DataFrame({"A":[1,2],"D":[23,24]},index=["a","b"])
var2.join(var1,how="inner")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 4>()
#       2 var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]},index=["a","b","c","d"])
#       3 var2= pd.DataFrame({"A":[1,2],"D":[23,24]},index=["a","b"])
# ----> 4 var2.join(var1,how="inner")
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:9254, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort)
#    9100 def join(
#    9101     self,
#    9102     other: DataFrame | Series,
#    (...)
#    9107     sort: bool = False,
#    9108 ) -> DataFrame:
#    9109     """
#    9110     Join columns of another DataFrame.
#    9111
#    (...)
#    9252     5  K1  A5   B1
#    9253     """
# -> 9254     return self._join_compat(
#    9255         other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9256     )
#
# ...

# %% [markdown]
# If there is any key is common in both Datatype than it shows error

# %%
import pandas as pd
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]},index=["a","b","c","d"])
var2= pd.DataFrame({"A":[1,2],"D":[23,24]},index=["a","b"])
var1.join(var2,how="inner",lsuffix="_12")
# Out:
#    A_12   B  A   D
# a     1  11  1  23
# b     2  12  2  24

# %%
import pandas as pd
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]},index=["a","b","c","d"])
var2= pd.DataFrame({"A":[1,2],"D":[23,24]},index=["a","b"])
var1.join(var2,how="inner",lsuffix="_12",rsuffix="_21")
# Out:
#    A_12   B  A_21   D
# a     1  11     1  23
# b     2  12     2  24

# %% [markdown]
# # Append

# %%
import pandas as pd
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]},index=["a","b","c","d"])
var2= pd.DataFrame({"A":[1,2],"D":[23,24]},index=["a","b"])
var1.append(var2)
# Out:
# C:\Users\Vikas Pandey\AppData\Local\Temp\ipykernel_2824\2090911918.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   var1.append(var2)
#    A     B     D
# a  1  11.0   NaN
# b  2  12.0   NaN
# c  3  13.0   NaN
# d  4  14.0   NaN
# a  1   NaN  23.0
# b  2   NaN  24.0

# %%
import pandas as pd
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]})
var2= pd.DataFrame({"A":[1,2],"D":[23,24]})
var1.append(var2)
# Out:
# C:\Users\Vikas Pandey\AppData\Local\Temp\ipykernel_2824\1816814146.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   var1.append(var2)
#    A     B     D
# 0  1  11.0   NaN
# 1  2  12.0   NaN
# 2  3  13.0   NaN
# 3  4  14.0   NaN
# 0  1   NaN  23.0
# 1  2   NaN  24.0

# %%
import pandas as pd
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]})
var2= pd.DataFrame({"A":[1,2],"D":[23,24]})
var1.append(var2,ignore_index=True)
# Out:
# C:\Users\Vikas Pandey\AppData\Local\Temp\ipykernel_2824\3099910116.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   var1.append(var2,ignore_index=True)
#    A     B     D
# 0  1  11.0   NaN
# 1  2  12.0   NaN
# 2  3  13.0   NaN
# 3  4  14.0   NaN
# 4  1   NaN  23.0
# 5  2   NaN  24.0
